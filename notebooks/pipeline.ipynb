# %%
# %matplotlib inline
# %run ../main.py
# Out:
# Support for PyTorch based likelihood models not available. To enable them, install "darts", "u8darts[torch]" or "u8darts[all]" (with pip); or "u8darts-torch" or "u8darts-all" (with conda).
# Support for Torch based models not available. To enable them, install "darts", "u8darts[torch]" or "u8darts[all]" (with pip); or "u8darts-torch" or "u8darts-all" (with conda).
# Đang xử lý dữ liệu...
# Kiểu dữ liệu của các cột trước khi xử lý:
# subjid        int64
# sex          object
# agedays     float64
# gagebrth      int64
# htcm        float64
# wtkg        float64
# haz         float64
# waz         float64
# dtype: object
#
# 5 dòng đầu của dữ liệu:
#    subjid     sex  agedays  gagebrth  htcm  wtkg    haz    waz
# 0   10001  Female      0.0       283  52.0  3.96  1.531  1.490
# 1   10001  Female     30.0       283  55.6  4.05  1.007 -0.215
# 2   10001  Female     58.0       283  58.2  4.56  0.700 -0.779
# 3   10001  Female     93.0       283  61.2  5.09  0.598 -1.143
# ...

# %%
# %run ../main.py
# Out:
# ===== BẮT ĐẦU QUY TRÌNH DỰ ĐOÁN CHIỀU CAO =====
# Đang xử lý dữ liệu chiều cao...
# Chiều cao - Dữ liệu thô:
# subjid        int64
# sex          object
# agedays     float64
# gagebrth      int64
# htcm        float64
# wtkg        float64
# haz         float64
# waz         float64
# dtype: object
#    subjid     sex  agedays  gagebrth  htcm  wtkg    haz    waz
# 0   10001  Female      0.0       283  52.0  3.96  1.531  1.490
# 1   10001  Female     30.0       283  55.6  4.05  1.007 -0.215
# 2   10001  Female     58.0       283  58.2  4.56  0.700 -0.779
# 3   10001  Female     93.0       283  61.2  5.09  0.598 -1.143
# 4   10001  Female    184.0       283  67.2  6.81  0.615 -0.586
#
# Chiều cao - Dữ liệu sau tiền xử lý cơ bản:
# subjid        int64
# sex           int64
# agedays       Int64
# gagebrth      int64
# htcm        float64
# wtkg        float64
# haz         float64
# waz         float64
# dtype: object
#    subjid  sex  agedays  gagebrth  htcm  wtkg    haz    waz
# ...

# %%
# %run ../main.py
# Out:
# Support for PyTorch based likelihood models not available. To enable them, install "darts", "u8darts[torch]" or "u8darts[all]" (with pip); or "u8darts-torch" or "u8darts-all" (with conda).
# Support for Torch based models not available. To enable them, install "darts", "u8darts[torch]" or "u8darts[all]" (with pip); or "u8darts-torch" or "u8darts-all" (with conda).
# ===== BẮT ĐẦU QUY TRÌNH DỰ ĐOÁN CHIỀU CAO =====
# Đang xử lý dữ liệu chiều cao...
# Chiều cao - Dữ liệu thô:
# subjid        int64
# sex          object
# agedays     float64
# gagebrth      int64
# htcm        float64
# wtkg        float64
# haz         float64
# waz         float64
# dtype: object
#    subjid     sex  agedays  gagebrth  htcm  wtkg    haz    waz
# 0   10001  Female      0.0       283  52.0  3.96  1.531  1.490
# 1   10001  Female     30.0       283  55.6  4.05  1.007 -0.215
# 2   10001  Female     58.0       283  58.2  4.56  0.700 -0.779
# 3   10001  Female     93.0       283  61.2  5.09  0.598 -1.143
# ...
