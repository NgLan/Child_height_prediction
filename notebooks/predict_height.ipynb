# %%
# %run "..\scripts\height_prediction_model.py"
# Out:
# Train MSE: 5.2829
# Test MSE: 5.1903
# Train R²: 0.9646
# Test R²: 0.9670
# Mô hình đã được lưu vào d:\Child_height_prediction\models\height_prediction_model.pkl
# Tập train/test đã được lưu vào d:\Child_height_prediction\models

# %%
# %run "..\scripts\child_classification_model.py"
# Out:
# Phân bố lớp trong dữ liệu gốc:
# category
# Normal                         715
# Possible risk of overweight    203
# Undernourished                  39
# Overweight                      34
# Obese                            3
# Name: count, dtype: int64
#
# Kiểm tra dữ liệu sau khi xử lý giá trị bất thường:
# agedays - min: 1, max: 978
# wtkg - min: 1.96, max: 16.0
# gagebrth - min: 227, max: 304
# htcm - min: 44.0, max: 95.0
# wtkg_per_agedays - min: 0.013292433537832311, max: 4.55
# bmi - min: 9.679, max: 22.751
#
# Phân bố lớp trong tập train:
# category
# 0    574
# 3    163
# 4     29
# 2     28
# 1      1
# Name: count, dtype: int64
# d:\Child_height_prediction\venv\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Best parameters: {'class_weight': 'balanced', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
#
# ...

# %%
# %run "..\scripts\child_classification_model.py"
# Out:
# Phân bố lớp trong dữ liệu gốc:
# category
# Normal                         715
# Possible risk of overweight    203
# Undernourished                  39
# Overweight                      34
# Obese                            3
# Name: count, dtype: int64
#
# Kiểm tra dữ liệu sau khi xử lý giá trị bất thường và loại bỏ lớp Obese:
# agedays - min: 1, max: 978
# wtkg - min: 1.96, max: 16.0
# htcm - min: 44.0, max: 95.0
# wtkg_per_agedays - min: 0.013292433537832311, max: 4.55
# bmi - min: 9.679, max: 21.691
#
# Phân bố lớp sau khi loại bỏ Obese:
# category
# Normal                         715
# Possible risk of overweight    203
# Undernourished                  39
# Overweight                      34
# Name: count, dtype: int64
#
# Phân bố lớp trong tập train:
# category
# 0    568
# 2    165
# 3     31
# 1     28
# Name: count, dtype: int64
#
# Best parameters: {'class_weight': 'balanced', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
#
# ...

# %%
# %run "..\scripts\child_classification_model.py"
# Out:
# Phân bố lớp trong dữ liệu gốc:
# category
# Normal                         715
# Possible risk of overweight    203
# Undernourished                  39
# Overweight                      34
# Obese                            3
# Name: count, dtype: int64
#
# Kiểm tra dữ liệu sau khi xử lý giá trị bất thường và loại bỏ lớp Obese:
# agedays - min: 1, max: 978
# wtkg - min: 1.96, max: 16.0
# htcm - min: 44.0, max: 95.0
# wtkg_per_agedays - min: 0.013292433537832311, max: 4.55
# bmi - min: 9.679, max: 21.691
#
# Phân bố lớp sau khi loại bỏ Obese:
# category
# Normal                         715
# Possible risk of overweight    203
# Undernourished                  39
# Overweight                      34
# Name: count, dtype: int64
#
# Phân bố lớp trong tập train:
# category
# 0    568
# 2    165
# 3     31
# 1     28
# Name: count, dtype: int64
#
# ...

# %%
# %run "..\scripts\child_classification_model.py"
# Out:
# Phân bố lớp trong dữ liệu gốc:
# category
# Normal            918
# Undernourished     39
# Overweight         37
# Name: count, dtype: int64
#
# Kiểm tra dữ liệu sau khi xử lý giá trị bất thường và loại bỏ lớp Obese:
# agedays - min: 1, max: 978
# wtkg - min: 1.96, max: 16.0
# htcm - min: 44.0, max: 95.0
# wtkg_per_agedays - min: 0.013292433537832311, max: 4.55
# bmi - min: 9.679, max: 22.751
#
# Phân bố lớp sau khi loại bỏ Obese:
# category
# Normal            918
# Undernourished     39
# Overweight         37
# Name: count, dtype: int64
#
# Phân bố lớp trong tập train:
# category
# 0    737
# 1     29
# 2     29
# Name: count, dtype: int64
#
# Best parameters: {'class_weight': {0: 1, 1: 10, 2: 20}, 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
#
# Train Accuracy: 0.9736
# Train Error Rate: 0.0264
# Test Accuracy: 0.9598
# Test Error Rate: 0.0402
#
# Classification Report (Test):
#                 precision    recall  f1-score   support
#
# ...

# %%
# %run "..\scripts\visualization.py"

# %%
# %run "..\scripts\visualization.py"
# Out:
# d:\Child_height_prediction\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Đã hoàn thành việc tạo các biểu đồ và lưu vào thư mục 'figures'.

# %%
# %run "..\scripts\child_classification_model.py"
# Out:
# Phân bố lớp trong dữ liệu gốc:
# category
# Normal            918
# Undernourished     39
# Overweight         37
# Name: count, dtype: int64
#
# Kiểm tra dữ liệu sau khi xử lý giá trị bất thường:
# agedays - min: 1, max: 978
# wtkg - min: 1.96, max: 16.0
# htcm - min: 44.0, max: 95.0
# wtkg_per_agedays - min: 0.013292433537832311, max: 4.55
# bmi - min: 9.679, max: 22.751
#
# Phân bố lớp sau khi xử lý:
# category
# Normal            918
# Undernourished     39
# Overweight         37
# Name: count, dtype: int64
# Mapping của LabelEncoder (lớp -> số):
# Normal: 0
# Overweight: 1
# Undernourished: 2
#
# Phân bố lớp trong tập train:
# category
# 0    737
# 1     29
# 2     29
# Name: count, dtype: int64
#
# Best parameters: {'class_weight': {0: 1, 1: 10, 2: 20}, 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
#
# Train Accuracy: 0.9736
# Train Error Rate: 0.0264
# Test Accuracy: 0.9598
# Test Error Rate: 0.0402
#
# Classification Report (Test):
# ...

# %%
# %run "..\scripts\visualization.py"

# %%
# %run "..\scripts\a.py"
# Out:
# Phân bố lớp trong dữ liệu gốc:
# category
# Normal            918
# Undernourished     39
# Overweight         37
# Name: count, dtype: int64
#
# Kiểm tra dữ liệu sau khi xử lý giá trị bất thường:
# agedays - min: 1, max: 978
# wtkg - min: 1.96, max: 16.0
# htcm - min: 44.0, max: 95.0
# wtkg_per_agedays - min: 0.013292433537832311, max: 4.55
# bmi - min: 9.679, max: 22.751
#
# Phân bố lớp sau khi xử lý:
# category
# Normal            918
# Undernourished     39
# Overweight         37
# Name: count, dtype: int64
#
# Sau Winsorization, wtkg_per_agedays - min: 0.013292433537832311 max: 4.04
#
# Mapping của LabelEncoder (lớp -> số):
# Normal: 0
# Overweight: 1
# Undernourished: 2
#
# Phân bố lớp trong tập train:
# category
# 0    737
# 1     29
# 2     29
# Name: count, dtype: int64
#
# Best parameters: {'class_weight': {0: 1, 1: 10, 2: 20}, 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
#
# Train Accuracy: 0.9736
# Train Error Rate: 0.0264
# ...

# %%
# %run "..\scripts\visualization.py"
